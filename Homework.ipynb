# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Problem 2.1
#https://see.stanford.edu/materials/lsoeldsee263/homeworkProblems.pdf

G=np.array([[1,0.2,0.1],[0.1,2,0.1],[0.3,0.1,3]])

gamma=3
alpha=1.2
sigma=0.01

# %%
p=np.array([[1],[3],[7]])
s=np.diag(np.diag(G))@p
q=sigma+(G-np.diag(G))@p

# %%
ts=np.array([[0],[0],[0]])
ts2=np.array([[0],[0],[0]])
for t in range(0,15):
    S=(np.diag(np.diag(G))@p)/(sigma+(G-np.diag(G))@p)  
    p=alpha*gamma*p/S
    ts2=np.hstack((ts2,S))
    ts=np.hstack((ts,p))

# %%
print(ts)
# Out:
# [[ 0.00000000e+00 -4.42301796e+10  2.85131576e+11 -1.83811720e+12
#    1.18495116e+13 -7.63885057e+13  4.92442382e+14 -3.17455539e+15
#    2.04649344e+16 -1.31928257e+17  8.50482306e+17 -5.48267806e+18
#    3.53443667e+19 -2.27849283e+20  1.46884215e+21 -9.46896666e+21]
#  [ 0.00000000e+00 -2.21150898e+10  1.42565788e+11 -9.19058598e+11
#    5.92475578e+12 -3.81942528e+13  2.46221191e+14 -1.58727770e+15
#    1.02324672e+16 -6.59641285e+16  4.25241153e+17 -2.74133903e+18
#    1.76721834e+19 -1.13924641e+20  7.34421075e+20 -4.73448333e+21]
#  [ 0.00000000e+00 -1.35848462e+10  8.75757557e+10 -5.64560521e+11
#    3.63947205e+12 -2.34620329e+13  1.51249241e+14 -9.75035916e+14
#    6.28561968e+15 -4.05205702e+16  2.61217949e+17 -1.68395497e+18
#    1.08557026e+19 -6.99818462e+19  4.51141580e+20 -2.90830746e+21]]

# %%
plt.plot(ts[:,1:].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f430f7ec490>,
#  <matplotlib.lines.Line2D at 0x7f430f7df650>,
#  <matplotlib.lines.Line2D at 0x7f430f7ec610>]

# %%
plt.plot(ts2[:,2:].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f430f6fec50>,
#  <matplotlib.lines.Line2D at 0x7f430f76f950>,
#  <matplotlib.lines.Line2D at 0x7f430f6fedd0>]
